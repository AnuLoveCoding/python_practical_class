# %%
# loops in python

# %%
i = 0
while i <= 5:
    print("Anurag") 
    i += 1
# Out:
# Anurag
# Anurag
# Anurag
# Anurag
# Anurag
# Anurag

# %%
i = 1
while i <= 10:
    if i % 2 == 0:
        print(i, end = " ")
    i += 1
# Out:
# 2 4 6 8 10

# %%
k = 1
sum = 0
while k <= 10:
    sum += k
    k += 1
print(sum)

# %%
print(sum)
