# %% [markdown]
# # Map method in function.

# %%
def add(a):
    return a + a

# %%
numbers = [4,6,7,8,9]

# %%
out = map(add, numbers)

# %%
add = list(out)

# %%
print(add)
# Out:
# [8, 12, 14, 16, 18]

# %%
di = map(lambda aa : (aa * aa),(45,6,4,5,1,2,3,5,6))

# %%
print(list(di))
# Out:
# [2025, 36, 16, 25, 1, 4, 9, 25, 36]

# %%
dii = map(lambda oo,pp : (oo * pp), (54,12),(14,16))

# %%
print(list(dii))
# Out:
# [756, 192]

# %%
kk = map(lambda o,p,q :(o + p + q),(5,6,7),(9,6,7),(10,6,7))

# %%
print(list(kk))
# Out:
# [24, 18, 21]

# %% [markdown]
# # Filter method in function;

# %%
def fill(a):
    if a >= 9:
        return a

# %%
out1 = filter(fill,[2,5,6,4,7,8,9,7,8,9])

# %%
print(list(out1))
# Out:
# [9, 9]

# %%
out2 = filter(lambda a : (a >= 5),(2,5,64,7,8,9,8,7,4,5,6))

# %%
print(list(out2))
# Out:
# [5, 64, 7, 8, 9, 8, 7, 5, 6]

# %%
out3 = filter(lambda b : (b <= 5),(4,2,1,5,4,6,7,1,2,0,1,4,5))

# %%
print(tuple(out3))
# Out:
# (4, 2, 1, 5, 4, 1, 2, 0, 1, 4, 5)

# %%
n = filter(lambda b : (b % 2 == 0),(4,5,6,7,8,9,14,12,35))

# %%
print(list(n))
# Out:
# [4, 6, 8, 14, 12]

# %%
n1 = filter(lambda c : (c % 2 == 1),(4,5,6,7,8,9,4,1,2,3,15))

# %%
print(tuple(n1))
# Out:
# (5, 7, 9, 1, 3, 15)

# %%
import reduce;
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14756\3271559822.py in <module>
# ----> 1 import reduce;
#
# ModuleNotFoundError: No module named 'reduce'

# %% [markdown]
# # Reduce method in function;

# %%
reduce(lambda a : a + a,(10, 20, 25, 45, 16))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14756\3032980478.py in <module>
# ----> 1 reduce(lambda a : a + a,(10,20,25,45,16))
#
# NameError: name 'reduce' is not defined
