# %%
f = open("content.txt", 'r')

# %% [markdown]
# # when we call read function, when text file will be open and we read also with letters.

# %%
# print(f.read(100))

# %%
g = open("content.txt" , 'r')

# %%
# print(g.read())

# %% [markdown]
# # when I  read file line by line then we iterate a loop over assign variable;

# %%
for l in g:
    print(l)
# Out:
# This is new key-pad
#
# This is my new name ANUrag
#
# This is my new name ANUrag
#
# This is my new name ANUrag
#
# This is my new name ANUrag
#
# This is my new name ANUrag

# %%
h = open('content.txt', 'w')

# %%
h.write('This is new key-pad \n')
# Out:
# 21

# %%
h.close()

# %%
k = open('content.txt', 'a')

# %%
k.write('This is my new name ANUrag \n')
# Out:
# 28

# %%
k.close()

# %%
u = open('content.txt','r')

# %%
for l in u:
    print(l)
# Out:
# This is new key-pad
#
# This is my new name ANUrag

# %%
u.close()

# %%
wa = open('content1.text', 'r')

# %%
print(wa.read())
# Out:
# Add first in a linklist
# Add last in a linklist
# Add at in a linklist
# Remove first in a linklist
# Remove Last in a linklist
# Remove at a linklist
# print linklist
# length of linklist
# Search k in a linklist
# Mid of linklist

# %%
wa.close()

# %%
gh = open('content1.text','w')

# %%
gh.write('Today i solve new_problem \n')
# Out:
# 27

# %%
gh.close()

# %%
kj = open('content1.text', 'a')

# %%
kj.write('Today i buy new_clothes')
# Out:
# 23

# %%
kj.close()

# %%
kl = open('content1.text','a')

# %%
kl.write('Ghost is comeing sonn \n')
# Out:
# 23

# %%
kl.close()

# %%
mn = open('content1.text','r')

# %%
print(mn.read())
# Out:
# Today i solve new_problem
# Today i buy new_clothesGhost is comeing sonn

# %%
mn.close()
